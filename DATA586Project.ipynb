# %% [markdown]
# ## DATA586 Project

# %% [markdown]
# ### Running experiment workflow on the resnet18 and efficientnet model
#
# Note that all experiment data and summary are retrieved and saved as log by the `run_experiment _workflow` function

# %%
from workflow import WorkflowConfig, run_experiment_workflow

# %% [markdown]
# #### 1. Running Resnet_18 Baseline Model

# %%
config = WorkflowConfig(
    model_name="resnet18_baseline",
    epochs=20,
    batch_size=32,
    num_workers=4,
    image_size=224,
    lr=1e-3,
    device="auto",
    use_validation_split=True,
    validation_proportion=0.1,
    evaluate_test_splits_after_training=True,
)

summary = run_experiment_workflow(config)
# Out:
# <div style='border:1px solid #cbd5e1;border-radius:12px;padding:12px 14px;background:#f8fafc;font-family:Segoe UI,Arial,sans-serif;'><div style='font-weight:700;color:#0f172a;margin-bottom:4px;'>Workflow: resnet18_baseline</div><div style='color:#334155;font-size:13px;'>Workflow finished</div><div style='margin-top:8px;'><div style='height:10px;border-radius:999px;background:#e2e8f0;overflow:hidden;'><div style='height:10px;width:100%;background:linear-gradient(90deg,#2563eb,#38bdf8);'></div></div><div style='margin-top:6px;font-size:12px;color:#475569;'>1/1 (100%)</div></div></div>

# %% [markdown]
# #### 2. Running EfficientNet Baseline Model

# %%
config = WorkflowConfig(
    model_name="efficientnet_baseline",
    epochs=20,
    batch_size=32,
    num_workers=4,
    image_size=224,
    lr=1e-3,
    device="auto",
    use_validation_split=True,
    validation_proportion=0.1,
    evaluate_test_splits_after_training=True,
)

summary = run_experiment_workflow(config)
# Out:
# <div style='border:1px solid #cbd5e1;border-radius:12px;padding:12px 14px;background:#f8fafc;font-family:Segoe UI,Arial,sans-serif;'><div style='font-weight:700;color:#0f172a;margin-bottom:4px;'>Workflow: efficientnet_baseline</div><div style='color:#334155;font-size:13px;'>Workflow finished</div><div style='margin-top:8px;'><div style='height:10px;border-radius:999px;background:#e2e8f0;overflow:hidden;'><div style='height:10px;width:100%;background:linear-gradient(90deg,#2563eb,#38bdf8);'></div></div><div style='margin-top:6px;font-size:12px;color:#475569;'>1/1 (100%)</div></div></div>

# %% [markdown]
# #### 3. Running Resnet_18 LoRA Model

# %%
config = WorkflowConfig(
    model_name="resnet18_lora",
    epochs=20,
    batch_size=32,
    num_workers=4,
    image_size=224,
    lr=1e-3,
    device="auto",
    use_validation_split=True,
    validation_proportion=0.1,
    evaluate_test_splits_after_training=True,
)

summary = run_experiment_workflow(config)
# Out:
# <div style='border:1px solid #cbd5e1;border-radius:12px;padding:12px 14px;background:#f8fafc;font-family:Segoe UI,Arial,sans-serif;'><div style='font-weight:700;color:#0f172a;margin-bottom:4px;'>Workflow: resnet18_lora</div><div style='color:#334155;font-size:13px;'>Workflow finished</div><div style='margin-top:8px;'><div style='height:10px;border-radius:999px;background:#e2e8f0;overflow:hidden;'><div style='height:10px;width:100%;background:linear-gradient(90deg,#2563eb,#38bdf8);'></div></div><div style='margin-top:6px;font-size:12px;color:#475569;'>1/1 (100%)</div></div></div>

# %% [markdown]
# #### 4. Running EfficientNet LoRA Model

# %%
config = WorkflowConfig(
    model_name="efficientnet_lora",
    epochs=20,
    batch_size=32,
    num_workers=4,
    image_size=224,
    lr=1e-3,
    device="auto",
    use_validation_split=True,
    validation_proportion=0.1,
    evaluate_test_splits_after_training=True,
)

summary = run_experiment_workflow(config)
# Out:
# <div style='border:1px solid #cbd5e1;border-radius:12px;padding:12px 14px;background:#f8fafc;font-family:Segoe UI,Arial,sans-serif;'><div style='font-weight:700;color:#0f172a;margin-bottom:4px;'>Workflow: efficientnet_lora</div><div style='color:#334155;font-size:13px;'>Workflow finished</div><div style='margin-top:8px;'><div style='height:10px;border-radius:999px;background:#e2e8f0;overflow:hidden;'><div style='height:10px;width:100%;background:linear-gradient(90deg,#2563eb,#38bdf8);'></div></div><div style='margin-top:6px;font-size:12px;color:#475569;'>1/1 (100%)</div></div></div>

# %% [markdown]
# #### 5. Running Resnet_18 TSA Model

# %%
config = WorkflowConfig(
    model_name="resnet18_tsa",
    epochs=20,
    batch_size=32,
    num_workers=4,
    image_size=224,
    lr=1e-3,
    device="auto",
    use_validation_split=True,
    validation_proportion=0.1,
    evaluate_test_splits_after_training=True,
)

summary = run_experiment_workflow(config)
# Out:
# <div style='border:1px solid #cbd5e1;border-radius:12px;padding:12px 14px;background:#f8fafc;font-family:Segoe UI,Arial,sans-serif;'><div style='font-weight:700;color:#0f172a;margin-bottom:4px;'>Workflow: resnet18_tsa</div><div style='color:#334155;font-size:13px;'>Workflow finished</div><div style='margin-top:8px;'><div style='height:10px;border-radius:999px;background:#e2e8f0;overflow:hidden;'><div style='height:10px;width:100%;background:linear-gradient(90deg,#2563eb,#38bdf8);'></div></div><div style='margin-top:6px;font-size:12px;color:#475569;'>1/1 (100%)</div></div></div>

# %% [markdown]
# #### 6. Running EfficientNet TSA Model

# %%
config = WorkflowConfig(
    model_name="efficientnet_tsa",
    epochs=20,
    batch_size=32,
    num_workers=4,
    image_size=224,
    lr=1e-3,
    device="auto",
    use_validation_split=True,
    validation_proportion=0.1,
    evaluate_test_splits_after_training=True,
)

summary = run_experiment_workflow(config)
# Out:
# <div style='border:1px solid #cbd5e1;border-radius:12px;padding:12px 14px;background:#f8fafc;font-family:Segoe UI,Arial,sans-serif;'><div style='font-weight:700;color:#0f172a;margin-bottom:4px;'>Workflow: efficientnet_tsa</div><div style='color:#334155;font-size:13px;'>Workflow finished</div><div style='margin-top:8px;'><div style='height:10px;border-radius:999px;background:#e2e8f0;overflow:hidden;'><div style='height:10px;width:100%;background:linear-gradient(90deg,#2563eb,#38bdf8);'></div></div><div style='margin-top:6px;font-size:12px;color:#475569;'>1/1 (100%)</div></div></div>

# %% [markdown]
# #### 7. Running Resnet_18 BN Tuning Model

# %%
config = WorkflowConfig(
    model_name="resnet18_bn_tuning",
    epochs=20,
    batch_size=32,
    num_workers=4,
    image_size=224,
    lr=1e-3,
    device="auto",
    use_validation_split=True,
    validation_proportion=0.1,
    evaluate_test_splits_after_training=True,
)

summary = run_experiment_workflow(config)
# Out:
# <div style='border:1px solid #cbd5e1;border-radius:12px;padding:12px 14px;background:#f8fafc;font-family:Segoe UI,Arial,sans-serif;'><div style='font-weight:700;color:#0f172a;margin-bottom:4px;'>Workflow: resnet18_bn_tuning</div><div style='color:#334155;font-size:13px;'>Workflow finished</div><div style='margin-top:8px;'><div style='height:10px;border-radius:999px;background:#e2e8f0;overflow:hidden;'><div style='height:10px;width:100%;background:linear-gradient(90deg,#2563eb,#38bdf8);'></div></div><div style='margin-top:6px;font-size:12px;color:#475569;'>1/1 (100%)</div></div></div>

# %% [markdown]
# #### 8. Running EfficientNet BN Tuning Model

# %%
config = WorkflowConfig(
    model_name="efficientnet_bn_tuning",
    epochs=20,
    batch_size=32,
    num_workers=4,
    image_size=224,
    lr=1e-3,
    device="auto",
    use_validation_split=True,
    validation_proportion=0.1,
    evaluate_test_splits_after_training=True,
)

summary = run_experiment_workflow(config)
# Out:
# <div style='border:1px solid #cbd5e1;border-radius:12px;padding:12px 14px;background:#f8fafc;font-family:Segoe UI,Arial,sans-serif;'><div style='font-weight:700;color:#0f172a;margin-bottom:4px;'>Workflow: efficientnet_bn_tuning</div><div style='color:#334155;font-size:13px;'>Workflow finished</div><div style='margin-top:8px;'><div style='height:10px;border-radius:999px;background:#e2e8f0;overflow:hidden;'><div style='height:10px;width:100%;background:linear-gradient(90deg,#2563eb,#38bdf8);'></div></div><div style='margin-top:6px;font-size:12px;color:#475569;'>1/1 (100%)</div></div></div>

# %% [markdown]
# #### 9. Running Resnet_18 Full Finetune Model

# %%
config = WorkflowConfig(
    model_name="resnet18_full_finetune",
    epochs=20,
    batch_size=32,
    num_workers=4,
    image_size=224,
    lr=1e-3,
    device="auto",
    use_validation_split=True,
    validation_proportion=0.1,
    evaluate_test_splits_after_training=True,
)

summary = run_experiment_workflow(config)
# Out:
# <div style='border:1px solid #cbd5e1;border-radius:12px;padding:12px 14px;background:#f8fafc;font-family:Segoe UI,Arial,sans-serif;'><div style='font-weight:700;color:#0f172a;margin-bottom:4px;'>Workflow: resnet18_full_finetune</div><div style='color:#334155;font-size:13px;'>Workflow finished</div><div style='margin-top:8px;'><div style='height:10px;border-radius:999px;background:#e2e8f0;overflow:hidden;'><div style='height:10px;width:100%;background:linear-gradient(90deg,#2563eb,#38bdf8);'></div></div><div style='margin-top:6px;font-size:12px;color:#475569;'>1/1 (100%)</div></div></div>

# %% [markdown]
# #### 10. Running EfficientNet Full Finetune Model

# %%
config = WorkflowConfig(
    model_name="efficientnet_full_finetune",
    epochs=20,
    batch_size=32,
    num_workers=4,
    image_size=224,
    lr=1e-3,
    device="auto",
    use_validation_split=True,
    validation_proportion=0.1,
    evaluate_test_splits_after_training=True,
)

summary = run_experiment_workflow(config)
# Out:
# <div style='border:1px solid #cbd5e1;border-radius:12px;padding:12px 14px;background:#f8fafc;font-family:Segoe UI,Arial,sans-serif;'><div style='font-weight:700;color:#0f172a;margin-bottom:4px;'>Workflow: efficientnet_full_finetune</div><div style='color:#334155;font-size:13px;'>Workflow finished</div><div style='margin-top:8px;'><div style='height:10px;border-radius:999px;background:#e2e8f0;overflow:hidden;'><div style='height:10px;width:100%;background:linear-gradient(90deg,#2563eb,#38bdf8);'></div></div><div style='margin-top:6px;font-size:12px;color:#475569;'>1/1 (100%)</div></div></div>
